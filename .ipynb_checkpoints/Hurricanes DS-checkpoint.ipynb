# %%
import pandas as pd

# %%
ds = pd.read_csv('Hurricanes1980sCurrentFlat.csv')

# %%
ds.head()
# Out:
#    Year    Mo Location1 WindDirection1 Location2 WindDirection2 Location3  \
# 0  1980   Aug        TX             S3       NaN            NaN       NaN
# 1  1981  None       NaN            NaN       NaN            NaN       NaN
# 2  1982  None       NaN            NaN       NaN            NaN       NaN
# 3  1983   Aug        TX             N3       NaN            NaN       NaN
# 4  1984   Sep      * NC              2       NaN            NaN       NaN
#
#   WindDirection3 Location4 WindDirection4 Location5  WindDirection5  Category  \
# 0            NaN       NaN            NaN       NaN             NaN       3.0
# 1            NaN       NaN            NaN       NaN             NaN       NaN
# 2            NaN       NaN            NaN       NaN             NaN       NaN
# 3            NaN       NaN            NaN       NaN             NaN       3.0
# 4            NaN       NaN            NaN       NaN             NaN       2.0
#
#    Centroid Pressure  Max Wind Speed    Name
# ...
